# %% [markdown]
# # BlockChain_V3.0
# A game that represents the basic operation of "Blockchain".

# %% [markdown]
# Šī ir spēle kas atspoguļo principiālo darbību tehnoloģījai blockchai. Ideja tika ņemta no šī [Lūk te](https://andersbrownworth.com/blockchain/) saita.
#
# bin/Debug/Blockchain Demo.exe šeit atrodas izpildāmais fails kuru var palaaist.
#
# Projekts skaitās nepabeigts. Bet Galvenie elementi strādā. Protams tikai pagaidām vienā "threadā" kas bloķē interfeisu uz skaitļošanas brīdi tā saukto "Maining".

# %% [markdown]
# ![Ekrānuzņēmums 2025-02-19 224852.png](data:image/png;base64,...)

# %% [markdown]
# ![Ekrānuzņēmums 2025-02-19 224906.png](data:image/png;base64,...)

# %% [markdown]
# Protams ir arī ir citas nepilnības kuras ietekmē programmas veiktspēju.
# Nākamo versīju izveidošu daudz efektīvāku un interesantāku, jau ir daudz ideju.
#
# Domāju nākamo verīju rakstīšu C++ vai Python.
#
# *   Protams sākšu lai skaitļošanu palaistu citā "threadā" lai nebloķētu interfeisu kā arī varēs iestatījumos izvēlēties cik thread vēlas izmantot skaitļošanai.
# *   Tiks pievienota iespēja skaitļot uz vidiokartes izmantojot cuda tehnoloģīju.
# *   Tiks pievienota iespēja caur websocket apvienot vairākus datorus.
# *   Un vēl domāju pievienot iespēju spēlēt ar citiem lietotājiem. Kas ļaus ēksperimentēt un sacensties ar citu spēlētāju datoru veiktspēju, jaudu.
# * Un galvenais pietuvināt spēles loģiku Bitcoi loģikai, cik nu man tas sanāks.
